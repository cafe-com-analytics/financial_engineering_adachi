# %%
import pandas as pd

# %%
df = pd.read_csv('../data/interim/ibovfull.csv')

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2016-01-04  17.730000  17.730000  17.209999  17.209999  14.775685
# 1  2016-01-05  17.250000  17.520000  17.110001  17.480000  15.007494
# 2  2016-01-06  17.360001  17.480000  17.200001  17.309999  14.861542
# 3  2016-01-07  17.170000  17.320000  16.850000  16.850000  14.466608
# 4  2016-01-08  16.930000  17.200001  16.930000  17.070000  14.655489
#
#        Volume   Name
# 0  13206900.0  ABEV3
# 1  10774200.0  ABEV3
# 2   7739100.0  ABEV3
# 3  15316400.0  ABEV3
# 4  10684000.0  ABEV3

# %%
goog = df[df['Name'] == 'ITUB4']
goog[['Close', 'Adj Close']].plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
aapl = df[df['Name'] == 'ABEV3']
aapl[['Close', 'Adj Close']].plot(figsize=(10,10))
# Out:
# <AxesSubplot:>
